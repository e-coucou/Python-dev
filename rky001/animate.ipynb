# %%
import numpy as np
import matplotlib.pyplot as plt
from  matplotlib import animation,rc
from IPython.display import HTML # updated

# %matplotlib notebook

k = 2*np.pi
w = 2*np.pi
dt = 0.01

xmin = 0
xmax = 3
nbx = 151

x = np.linspace(xmin, xmax, nbx)

fig = plt.figure() # initialise la figure
line, = plt.plot([], []) 
plt.xlim(xmin, xmax)
plt.ylim(-1, 1)

def animate(i): 
    t = i * dt
    y = np.cos(k*x - w*t)
    line.set_data(x, y)
    return line,
 
anim = animation.FuncAnimation(fig, animate, frames=100, blit=True, interval=20, repeat=False)

# plt.show()
plt.close() # updated
HTML(anim.to_html5_video()) # updated
# Out:
# <div id='f4b17484-03cf-4b98-b442-01b5cf55780a'></div>
# <video width="432" height="288" controls autoplay>
#   <source type="video/mp4" src="...

# %%
k = 2*np.pi
w = 2*np.pi
dt = 0.01

xmin = 0
xmax = 3
nbx = 151

x = np.linspace(xmin, xmax, nbx)

fig = plt.figure() # initialise la figure
line, = plt.plot([], []) 
plt.xlim(xmin, xmax)
plt.ylim(-1, 1)

def init():
    line.set_data([], [])
    return line,

def animate(i): 
    t = i * dt
    y = np.cos(k*x - w*t)
    line.set_data(x, y)
    return line,
 
ani = animation.FuncAnimation(fig, animate, init_func=init, frames=100, blit=True, interval=20, repeat=False)

# plt.show()
plt.close() # updated
HTML(anim.to_html5_video()) # updated
# Out:
# <div id='e996bed1-6ad6-47df-936d-8baa811189a4'></div>
# /Users/rky/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py:889: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you have outputted the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/rky/Documents/GitHub/Python-dev/rky001/animate.ipynb Cell 2' in <cell line: 30>()
#      <a href='vscode-notebook-cell:/Users/rky/Documents/GitHub/Python-dev/rky001/animate.ipynb#ch0000001?line=27'>28</a> # plt.show()
#      <a href='vscode-notebook-cell:/Users/rky/Documents/GitHub/Python-dev/rky001/animate.ipynb#ch0000001?line=28'>29</a> plt.close() # updated
# ---> <a href='vscode-notebook-cell:/Users/rky/Documents/GitHub/Python-dev/rky001/animate.ipynb#ch0000001?line=29'>30</a> HTML(anim.to_html5_video())
#
# File ~/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py:1266, in Animation.to_html5_video(self, embed_limit)
#    <a href='file:///Users/rky/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py?line=1262'>1263</a> path = Path(tmpdir, "temp.m4v")
#    <a href='file:///Users/rky/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py?line=1263'>1264</a> # We create a writer manually so that we can get the
#    <a href='file:///Users/rky/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py?line=1264'>1265</a> # appropriate size for the tag
# -> <a href='file:///Users/rky/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py?line=1265'>1266</a> Writer = writers[mpl.rcParams['animation.writer']]
#    <a href='file:///Users/rky/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py?line=1266'>1267</a> writer = Writer(codec='h264',
#    <a href='file:///Users/rky/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py?line=1267'>1268</a>                 bitrate=mpl.rcParams['animation.bitrate'],
#    <a href='file:///Users/rky/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py?line=1268'>1269</a>                 fps=1000. / self._interval)
#    <a href='file:///Users/rky/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py?line=1269'>1270</a> self.save(str(path), writer=writer)
#
# File ~/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py:151, in MovieWriterRegistry.__getitem__(self, name)
#     <a href='file:///Users/rky/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py?line=148'>149</a> if self.is_available(name):
#     <a href='file:///Users/rky/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py?line=149'>150</a>     return self._registered[name]
# --> <a href='file:///Users/rky/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py?line=150'>151</a> raise RuntimeError(f"Requested MovieWriter ({name}) not available")
#
# RuntimeError: Requested MovieWriter (ffmpeg) not available

# %%
rc('animation', html='html5')

# %%
# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return (line,)
# animation function. This is called sequentially
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return (line,)
# call the animator. blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)

HTML(anim.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/rky/Documents/GitHub/Python-dev/rky001/animate.ipynb Cell 4' in <cell line: 15>()
#      <a href='vscode-notebook-cell:/Users/rky/Documents/GitHub/Python-dev/rky001/animate.ipynb#ch0000003?line=10'>11</a> # call the animator. blit=True means only re-draw the parts that have changed.
#      <a href='vscode-notebook-cell:/Users/rky/Documents/GitHub/Python-dev/rky001/animate.ipynb#ch0000003?line=11'>12</a> anim = animation.FuncAnimation(fig, animate, init_func=init,
#      <a href='vscode-notebook-cell:/Users/rky/Documents/GitHub/Python-dev/rky001/animate.ipynb#ch0000003?line=12'>13</a>                                frames=100, interval=20, blit=True)
# ---> <a href='vscode-notebook-cell:/Users/rky/Documents/GitHub/Python-dev/rky001/animate.ipynb#ch0000003?line=14'>15</a> HTML(anim.to_html5_video())
#
# File ~/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py:1266, in Animation.to_html5_video(self, embed_limit)
#    <a href='file:///Users/rky/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py?line=1262'>1263</a> path = Path(tmpdir, "temp.m4v")
#    <a href='file:///Users/rky/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py?line=1263'>1264</a> # We create a writer manually so that we can get the
#    <a href='file:///Users/rky/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py?line=1264'>1265</a> # appropriate size for the tag
# -> <a href='file:///Users/rky/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py?line=1265'>1266</a> Writer = writers[mpl.rcParams['animation.writer']]
#    <a href='file:///Users/rky/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py?line=1266'>1267</a> writer = Writer(codec='h264',
#    <a href='file:///Users/rky/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py?line=1267'>1268</a>                 bitrate=mpl.rcParams['animation.bitrate'],
#    <a href='file:///Users/rky/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py?line=1268'>1269</a>                 fps=1000. / self._interval)
#    <a href='file:///Users/rky/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py?line=1269'>1270</a> self.save(str(path), writer=writer)
#
# File ~/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py:151, in MovieWriterRegistry.__getitem__(self, name)
#     <a href='file:///Users/rky/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py?line=148'>149</a> if self.is_available(name):
#     <a href='file:///Users/rky/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py?line=149'>150</a>     return self._registered[name]
# --> <a href='file:///Users/rky/opt/anaconda3/envs/newtry/lib/python3.10/site-packages/matplotlib/animation.py?line=150'>151</a> raise RuntimeError(f"Requested MovieWriter ({name}) not available")
#
# RuntimeError: Requested MovieWriter (ffmpeg) not available

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython import display

plt.rcParams['animation.ffmpeg_path'] = '/usr/local/bin/ffmpeg'

x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)

fig, ax = plt.subplots()
line, = ax.plot([])   # A tuple unpacking to unpack the only plotax.set_xlim(0, 2*np.pi)
ax.set_ylim(-1.1, 1.1)
def animate(frame_num):
    y = np.sin(x + 2*np.pi * frame_num/100)
    line.set_data((x, y))
    return line

anim = FuncAnimation(fig, animate, frames=100, interval=20)

video = anim.to_html5_video()
html = display.HTML(video)
display.display(html)
plt.close()                   # avoid plotting a spare static plot
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/rky/Documents/GitHub/Python-dev/rky001/animate.ipynb Cell 5' in <cell line: 21>()
#      <a href='vscode-notebook-cell:/Users/rky/Documents/GitHub/Python-dev/rky001/animate.ipynb#ch0000004?line=16'>17</a>     return line
#      <a href='vscode-notebook-cell:/Users/rky/Documents/GitHub/Python-dev/rky001/animate.ipynb#ch0000004?line=18'>19</a> anim = FuncAnimation(fig, animate, frames=100, interval=20)
# ---> <a href='vscode-notebook-cell:/Users/rky/Documents/GitHub/Python-dev/rky001/animate.ipynb#ch0000004?line=20'>21</a> video = anim.to_html5_video()
#      <a href='vscode-notebook-cell:/Users/rky/Documents/GitHub/Python-dev/rky001/animate.ipynb#ch0000004?line=21'>22</a> html = display.HTML(video)
#      <a href='vscode-notebook-cell:/Users/rky/Documents/GitHub/Python-dev/rky001/animate.ipynb#ch0000004?line=22'>23</a> display.display(html)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/animation.py:1266, in Animation.to_html5_video(self, embed_limit)
#    <a href='file:///Users/rky/opt/anaconda3/lib/python3.9/site-packages/matplotlib/animation.py?line=1262'>1263</a> path = Path(tmpdir, "temp.m4v")
#    <a href='file:///Users/rky/opt/anaconda3/lib/python3.9/site-packages/matplotlib/animation.py?line=1263'>1264</a> # We create a writer manually so that we can get the
#    <a href='file:///Users/rky/opt/anaconda3/lib/python3.9/site-packages/matplotlib/animation.py?line=1264'>1265</a> # appropriate size for the tag
# -> <a href='file:///Users/rky/opt/anaconda3/lib/python3.9/site-packages/matplotlib/animation.py?line=1265'>1266</a> Writer = writers[mpl.rcParams['animation.writer']]
#    <a href='file:///Users/rky/opt/anaconda3/lib/python3.9/site-packages/matplotlib/animation.py?line=1266'>1267</a> writer = Writer(codec='h264',
#    <a href='file:///Users/rky/opt/anaconda3/lib/python3.9/site-packages/matplotlib/animation.py?line=1267'>1268</a>                 bitrate=mpl.rcParams['animation.bitrate'],
#    <a href='file:///Users/rky/opt/anaconda3/lib/python3.9/site-packages/matplotlib/animation.py?line=1268'>1269</a>                 fps=1000. / self._interval)
#    <a href='file:///Users/rky/opt/anaconda3/lib/python3.9/site-packages/matplotlib/animation.py?line=1269'>1270</a> self.save(str(path), writer=writer)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/animation.py:151, in MovieWriterRegistry.__getitem__(self, name)
#     <a href='file:///Users/rky/opt/anaconda3/lib/python3.9/site-packages/matplotlib/animation.py?line=148'>149</a> if self.is_available(name):
#     <a href='file:///Users/rky/opt/anaconda3/lib/python3.9/site-packages/matplotlib/animation.py?line=149'>150</a>     return self._registered[name]
# --> <a href='file:///Users/rky/opt/anaconda3/lib/python3.9/site-packages/matplotlib/animation.py?line=150'>151</a> raise RuntimeError(f"Requested MovieWriter ({name}) not available")
#
# RuntimeError: Requested MovieWriter (ffmpeg) not available
